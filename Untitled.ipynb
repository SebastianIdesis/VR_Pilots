# %%
import numpy as np

# %%
import pyxdf

# %%
# Load the XDF file
file_path = "./Data/55_Georgius_pilot_Javad_onlyTelefonica_Breating_EEG_GSR.xdf"

streams, header = pyxdf.load_xdf(file_path)

# %%
for i in range(len(streams)):
    streams[i]['info']['name']
    print(streams[i]['info']['name'])
# Out:
# ['Game_Markers']
# ['Coaster']
# ['FMS_Score']
# ['HMD_MotionData']
# ['actiCHamp-24020270']
# ['actiCHampMarkers-24020270']

# %%
streams[0]['time_stamps'][-1] - streams[0]['time_stamps'][0]
# Out:
# np.float64(588.7469942950411)

# %%
588/60
# Out:
# 9.8
